# %%
잔디콘
깃헙관리 공부

TIL

# %% [markdown]
# 11:20 ~ 12:00
# Clean Architecture, 카카오톡 샾(#)탭 적용기
#
# #Android #Kotlin
# Latte
#
#
# 코틀린 kotlin
#
#
# platform application
# usecase application
#
# -> dependency rule
#
#
# 탭의 구조 및 문제점
# MV VM
#
# view model
# VM이 커지는 문제

# %% [markdown]
# 12:10 ~ 12:50
# Nature of Code: 나만의 생태계 만들어보기
# #Physics #Simulation
# Kevin
#
# nature of code 책
# 컴퓨터로 자연을 그리는 법
# 기초 물리학 이용
#
# youtube: the coding train
#
#
# 커스텀 뷰 애니메이션 제작 게임클라이언트
#
#
#
# https://natureofjandi.com/
#
#
# random
# ->너무랜덤
#
# perlin noise함수
# brings a naturally ordered random line
#
# 원
#
# 안개그리기 - > 픽셀에 랜덤값, perlin noise값
#
#
#
#
# force 힘
# 모든 움직임의 원천
# 위치 가속도 속도 힘 관계
#
# 위치 = 위치+속도
# 속도 = 속도+가속도
# 가속도 = 가속도+힘
#
#
# 공기저항
#
#
# websocket
# react

# %% [markdown]
# 14:00 ~ 14:50
# 데이터로 인과관계 추론하기
# #입문 #코딩없음
# Miika
#
# 데이터를 분석하거나
# 분석관련 도구를 만듦

# %% [markdown]
# 15:00 ~ 15:30
# 천재 개발자도 내집은 필요할테니깐...
# #부동산
# Lev

# %% [markdown]
# 15:40 ~ 16:20
# Konva.js와 함께하는 canvas 2d 그래픽
# #Web
# June

# %% [markdown]
# 16:30 ~ 18:00
# 내 손으로 만드는 한국어 감정 분석기 실습
# #딥러닝
# Kyle
#
#
# 감정분석
# 텍스트 긍정 부정 분류
# 인종차별 분류
#
# translation
# chatbot
# language modeling etc
#
# seq2seq라는 모델
# text classification에 기반함
#
#
# audio -> spectrogram으로 인식
# image -> 픽셀로 인식
# text -> 컴퓨터가 바로 인식 불가
# 나 와 너 라는 단어 사이 continuous하지 않음
#
#
#
#
# 기술
# ## 'Native Bays'
# -bag of Words
# 잔디콘은 짱이에요 -> 잔디콘은,짱이에요
# counting을 함
# 짱이에요가 counting으로 긍정이 많아서 확률
#
# 긍정인 단어중에 짱이에요라는 단어가 몇번 나오는지 count후 frequency추출 후
# classification으로 긍정문으로 추출
#
#
# -sparse representation
# 강아지
# 긍정/부정으로 카운팅 가능하지만
#
# 멍멍이
# 컴터입장에서 완전 다른단어
# 다른 카운트가 됨
#
# -> dense representation , vector
# 단어간의 관계는 단어간의 거리다
# 강아지와 멍멍이간의 거리가 짧으면 비슷한 단어로 분류
#
# vector을 찾기위한 방법
# 단어의 의미로 찾음
# 단어 주변/맥락으로 정의되는 단어의 의미
#
# 다른 단어들과의 관계로 인해 정의되는 단어의 의미
# 타자화
#
# Distribution hypothesis
# 단어와 비슷한 주변은 비슷한 의미를 갖고있다
#
# i want ? food tonight
# italian mexican chair
#
# Continuous Bag of Words
# 잔디콘 vector 짱이에요 vector
# 평균을 내서
# vector의 위치에 따라 긍정과 부정을 classification
#
# Word2Vec
# Glove etc
#
#
# ## Tokenization: word, morph, character
# text의 분절에 대한 고민
#
#
# 형태소 분석기의 문제 = 복잡, 한국어에서 되는건 영어에서 안됨, 신조어나 오타에 대응이 어려움
# 이러한 문제를 타개
# 좀더 단순하게 할 방법은?
# Subwords!
# 짱이에요 -> 짱이, 이에, 에요 (2letter로 봄)
#
# 문장에서 단어의 순서는 중요하지 않나?
# 한국어 왼쪽에서 오른쪽으로 읽고
# 단어가 뭐가 먼저나오는지 중요 도치 등
#
# ## (현재 번역에서 많이 쓰이는 알고리즘)
# LSTM으로 해결!
# Recurrent Netural Network:우리의 기억은 읽으면서 기억을 하고 최종적인 기억으로 그 문장의 표현에 대한 의미 결과를 도출
#
# 문제는: 기억을 업데이트를 계속하는데, 이전에 나온 단어를 자꾸 까먹음
# 긴 문장인 경우 앞을 까먹음
#
#
#
# ## CNN(이미지분류시 사용 알고리즘)
# Convolutional Netural Network를 참조 가능
# 이미지는 지역성(픽셀)이 있어서 분류가 잘 됨
#
# (순서분류) 텍스트에 사용 할 수 있을것인가?
#
#
#
# 단어를 이해하기 위해 주변단어만 보면 된다(옆의 두단어 옆의 세단어)
#
#
# ## 2017년 Transformer
# 사람은 글을 읽을때 한 단어를 이해하기 위해 attention함
#
# 이제 모델도 attend to important words
#
# ## 2018년 10월 BERT
# training시킬때 labelling하여 classification함->사람이 함
# 세상에 널린 unlabeled된 text들을 사람이 어떻게 전부 label할까
#
# 1. Guess tbe missing words
# 단어 빈칸 맞추기를 기계한테 학습시킴
# 기계에게 언어에 대한 이해를 높임
# 문장에 대해서 적용
#
# wiki에 빈칸 뚫고
# 풀게 시킴
# 그러면 문장에 대한 vector이 정확해짐
#
# 1.1. semi-supervised  : wiki 단어 빈칸 맞추기
# 1.2. supervised
#
#
# 신조어를 모델이 단어가 뭔지를 추론하게 하는 방법
# 완전히 새로운 단어들은 대부분 기존 단어를 변형 혹은 합성
# 잔디콘은
# 은-조사
# 콘-콘퍼런스
# (잔디콘, 파이콘)->vector값 추출
# 잔디가 어려워짐
#
#
# lgcns 한국어 q&a set -> 코쿼드
#
#
# 형태소 코엔엘파이 카이
#
#
#
# yunkimcnn
#
#
#
#
# 아이디어:
# 백과사전에 있는 단어-의미 data로 크롤링해와서
# text들의 의미들을 classification 할 수 있진않을까?
#
# 동의어들의 의미들
# 사람 = 인간, 인물
#
# 의미만 가지고 단어를 맞추도록/동의어를 맞추도록 학습시킬 수 있을까?
# 백과사전의 단어와 정의
#
# 이런 동의어들의 거리vector이 짧아지는건가?
